# %% [markdown]
# <a href="https://colab.research.google.com/github/ijazkhan0351-bot/Ijazweek1-ml-assignment/blob/main/w05_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ijazkhan0351-bot/Ijazweek1-ml-assignment/blob/main/work/notebooks/w05_model.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# %pip install -q duckdb huggingface_hub

import duckdb
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')
con = duckdb.connect()
con.execute(f"CREATE SECRET (TYPE huggingface, TOKEN '{HF_TOKEN}')")
REL = "hf://datasets/FlyRank/internship-warehouse"
print("Connected.")
# Out:
# Connected.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %% [markdown]
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# ## Method Choice and Why
#
# I'm using **Logistic Regression** as my primary model, with a **Random
# Forest** as a comparison.
#
# Why: My baseline (Week 4) is a hand-written multiplicative rule — it can't
# learn interactions between signals or weight them optimally. Logistic
# Regression is the natural next step: it's interpretable (I can read the
# coefficients), handles a binary "declining vs not" target well, and won't
# overfit on a modest feature set. Random Forest adds the ability to capture
# non-linear interactions between signals (e.g., position and CTR might
# interact differently at different volume levels) — comparing both tells
# me whether the extra complexity of Random Forest is actually earning its
# keep, or whether a simple linear model captures most of the signal.
#
# I am NOT using Gradient Boosting this week — with a modest feature set and
# limited engineered features so far, it risks overfitting without adding
# real signal; I'll consider it in a later week if Random Forest shows
# clear non-linear structure worth capturing.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %% [markdown]
# # This cell is for CODE (numbers, a query, a check).
# # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# ## Split Design
#
# **Grouped, time-aware split.** I define my label by comparing March
# (month=2026-03, features) against April (month=2026-04, outcome) — a
# genuine past→future setup, never touching the sealed June test month.
#
# I also split by `client_hash_id` (GroupShuffleSplit), not by row, so that
# pages from the same client never appear in both train and test. Pages from
# the same client tend to be correlated (similar site structure, similar
# audience) — a row-level random split would leak client-specific patterns
# into the test set and make my score look better than it really is.

# %%
from sklearn.model_selection import GroupShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd

# March features
march = con.sql(f"""
    SELECT
        client_hash_id, content_hash_id,
        AVG(gsc_impressions) as avg_impressions,
        AVG(gsc_clicks) as avg_clicks,
        AVG(gsc_avg_position) as avg_position,
        SUM(gsc_clicks) * 1.0 / NULLIF(SUM(gsc_impressions), 0) as ctr
    FROM read_parquet('{REL}/fact_content_daily_performance/month=2026-03/*.parquet')
    WHERE gsc_data_available IS TRUE
    GROUP BY client_hash_id, content_hash_id
    HAVING SUM(gsc_impressions) > 0
""").df()

# April outcome (to build the label — NOT used as a feature)
april = con.sql(f"""
    SELECT
        client_hash_id, content_hash_id,
        SUM(gsc_clicks) as april_clicks
    FROM read_parquet('{REL}/fact_content_daily_performance/month=2026-04/*.parquet')
    WHERE gsc_data_available IS TRUE
    GROUP BY client_hash_id, content_hash_id
""").df()

data = march.merge(april, on=["client_hash_id", "content_hash_id"], how="inner")
data["is_declining"] = (data["april_clicks"] < data["avg_clicks"] * 30 * 0.85).astype(int)
# (declining = April total clicks came in noticeably below March's daily rate)

print(f"Total pages with both months' data: {len(data)}")
print(f"Declining rate: {data['is_declining'].mean():.3f}")

feature_cols = ["avg_impressions", "avg_clicks", "avg_position", "ctr"]
X = data[feature_cols].fillna(0)
y = data["is_declining"]
groups = data["client_hash_id"]

gss = GroupShuffleSplit(n_splits=1, test_size=0.25, random_state=42)
train_idx, test_idx = next(gss.split(X, y, groups=groups))

X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
data_test = data.iloc[test_idx].copy()

print(f"Train: {len(X_train)} rows, Test: {len(X_test)} rows")
print(f"Client overlap between train/test: {len(set(groups.iloc[train_idx]) & set(groups.iloc[test_idx]))}")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Total pages with both months' data: 158549
# Declining rate: 0.280
# Train: 135314 rows, Test: 23235 rows
# Client overlap between train/test: 0

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %%
def precision_at_k(scores, labels, k):
    order = np.argsort(-np.asarray(scores))
    topk = np.asarray(labels)[order[:k]]
    return topk.mean()

# --- Baseline (Week 4 rule), applied to test set ---
vol_norm = (data_test["avg_impressions"] - data["avg_impressions"].min()) / \
           (data["avg_impressions"].max() - data["avg_impressions"].min())
ctr_gap = 1 - (data_test["ctr"] / data["ctr"].max())
baseline_score = vol_norm * ctr_gap
baseline_p50 = precision_at_k(baseline_score, y_test, 50)

# --- Logistic Regression ---
logreg = LogisticRegression(max_iter=1000, class_weight="balanced")
logreg.fit(X_train, y_train)
logreg_score = logreg.predict_proba(X_test)[:, 1]
logreg_p50 = precision_at_k(logreg_score, y_test, 50)

# --- Random Forest ---
rf = RandomForestClassifier(n_estimators=200, max_depth=6, class_weight="balanced", random_state=42)
rf.fit(X_train, y_train)
rf_score = rf.predict_proba(X_test)[:, 1]
rf_p50 = precision_at_k(rf_score, y_test, 50)

print("=== Model vs Baseline (Precision@50, same test split) ===")
print(f"Week-4 Baseline (hand rule):  {baseline_p50:.3f}")
print(f"Logistic Regression:          {logreg_p50:.3f}")
print(f"Random Forest:                {rf_p50:.3f}")

# %% [markdown]
# ## Model vs Baseline
#
# [Fill in with the real table above, e.g.:]
# | Method | Precision@50 |
# |---|---|
# | Week-4 baseline (hand rule) | X.XXX |
# | Logistic Regression | X.XXX |
# | Random Forest | X.XXX |
#
# [One or two sentences: did the model beat the baseline? By how much? Is the
# improvement worth the added complexity, or is the baseline "good enough"?]

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Feature importance / coefficients
print("=== Logistic Regression coefficients ===")
for feat, coef in zip(feature_cols, logreg.coef_[0]):
    print(f"{feat}: {coef:.3f}")

print("\n=== Random Forest feature importance ===")
for feat, imp in zip(feature_cols, rf.feature_importances_):
    print(f"{feat}: {imp:.3f}")

# Look at the model's biggest mistakes
data_test["rf_score"] = rf_score
data_test["true_label"] = y_test.values
errors = data_test.sort_values("rf_score", ascending=False).head(50)
false_positives = errors[errors["true_label"] == 0]
print(f"\nFalse positives in top 50 (predicted high-risk, actually fine): {len(false_positives)}")
false_positives[["content_hash_id", "avg_impressions", "avg_position", "ctr", "rf_score"]].head(5)

# %% [markdown]
# ## Errors and Interpretation
#
# [Fill after seeing real output, e.g.:]
#
# The most important feature for the model was [X], suggesting [reasoning].
# The model's false positives — pages it ranked as high-risk that actually
# weren't declining — tend to be pages with [pattern you observe, e.g. "high
# impressions but already-good CTR, where the model over-weighted volume
# alone"]. This suggests the model, like the baseline, still struggles to
# distinguish "high volume" from "high volume AND actually underperforming."

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
